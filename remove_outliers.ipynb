# %%
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv('labeled-data.csv')

# Specify the column with 'F3' feature
f3_values = df['F3']

# Calculate the Z-scores for 'F3'
z_scores = stats.zscore(f3_values)

# Set a threshold for Z-scores to identify outliers
threshold = 3  # You can adjust this threshold based on your requirements

# Find the indices of outliers
outlier_indices = (z_scores > threshold) | (z_scores < -threshold)

# Remove the rows containing outliers
df_no_outliers = df[~outlier_indices]

# Display the shape of the original and cleaned dataframes
print(f"Original DataFrame shape: {df.shape}")
print(f"DataFrame shape after removing 'F3' outliers: {df_no_outliers.shape}")
# Out:
# Original DataFrame shape: (1537, 12)
# DataFrame shape after removing 'F3' outliers: (1535, 12)

# %%
features = df.iloc[:, 2:5]
# Combine features with labels
df_combined = pd.concat([features, df['label']], axis=1)

# Plot a pair plot
sns.pairplot(df_combined, hue='label', diag_kind='kde')
plt.suptitle('Pair Plot for Features')
plt.show()
